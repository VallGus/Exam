# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # "My Jupyter Notebook on IBM Watson Studio"

# %% [markdown]
# __Gabriele__<br>
# Digital Manager

# %% [markdown]
# _My job is currently manage a team of people. I want to learn data science to take better decision based on data evidences_

# %% [markdown]
# ### Code to print "Hello World"

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# I am trying:
# -  bullet 1
# -  bullet 2
# -  bullet 3
#
# ***
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/c/c3/Python-logo-notext.svg/1200px-Python-logo-notext.svg.png" alt="Alt text that describes the graphic" title="Title text" width=100px/>
